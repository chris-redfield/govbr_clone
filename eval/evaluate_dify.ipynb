# %%
import pandas as pd
import os
from cogfy_manager import CogfyClient
from urllib.parse import urljoin
import requests
from tqdm.notebook import tqdm
from dotenv import load_dotenv
import json

# %%
load_dotenv()

df = pd.read_csv("../dataset/scripts_dataset.csv")
df
# Out:
#                                              pergunta  \
# 0   Quais serviços estão disponíveis nos balcões d...
# 1   Qual suporte vocês oferecem para problemas enc...
# 2   Como faço para obter um arquivo com o registro...
# 3   Qual é o número de telefone para atendimento s...
# 4   Como posso deixar uma avaliação positiva sobre...
# ..                                                ...
# 74  Como faço para acessar os serviços de Imposto ...
# 75  Como um MEI pode acessar e melhorar o nível da...
# 76  Como posso acessar os serviços do Meu INSS se ...
# 77  Como posso acessar e utilizar o sistema Regist...
# 78  Como posso consultar e solicitar a devolução d...
#
#                                     classe  \
# 0           Geral – Atendimento Presencial
# 1    Geral - Problema em sistemas diversos
# 2      Geral - Arquivo da conversa no chat
# 3           Geral - Atendimento telefônico
# 4                          Geral - Elogios
# ..                                     ...
# ...

# %%
k = os.environ["DIFY_API_KEY"]
api_url = "http://localhost/v1/chat-messages"

headers = {
    "Authorization": f"Bearer {k}",
    "Content-Type": "application/json"
}

# %%
params = {
    "inputs": {},
    "query": "oi, tudo bem ?",
    "response_mode": "blocking",
    "user": "evaluation_user"
}

# response = requests.post(api_url, headers=headers, json=params)
# response.raise_for_status()  # Raise an exception for bad status codes

# %%
# response.text

# %%
# json.loads(response.text)['answer']

# %%
params = {
    "inputs": {},
    "query": "",
    "response_mode": "blocking",
    "user": "evaluation_user"
}

# %%
df["response_dify"] = ""

for idx, row in tqdm(df.iterrows(), total=len(df)):
    print(row.pergunta)
    
    params["query"] = row.pergunta

    response = requests.post(api_url, headers=headers, json=params)
    response.raise_for_status()  # Raise an exception for bad status codes
    
    # print(response)
    df.loc[idx, 'response_dify'] = json.loads(response.text)['answer']
# Out:
#   0%|          | 0/79 [00:00<?, ?it/s]
# Quais serviços estão disponíveis nos balcões de atendimento presencial do gov.br e onde posso encontrar mais informações sobre eles?
# Qual suporte vocês oferecem para problemas encontrados no sistema de emissão de passaportes?
# Como faço para obter um arquivo com o registro desta conversa no chat?
# Qual é o número de telefone para atendimento sobre assuntos relacionados ao gov.br?
# Como posso deixar uma avaliação positiva sobre os serviços do gov.br?
# Como posso enviar uma sugestão para a melhoria dos serviços públicos digitais do governo?
# Como posso fazer uma reclamação sobre um serviço público federal?
# Por que meu processo de verificação de identidade foi rejeitado ao tentar acessar o serviço online usando meu CPF?
# Como posso confirmar se o processo de verificação de identidade na minha conta foi completado corretamente?
# Por que estou recebendo o erro 403 ao tentar acessar o site e como posso resolver isso?
# ...

# %%
df
# Out:
#                                              pergunta  \
# 0   Quais serviços estão disponíveis nos balcões d...
# 1   Qual suporte vocês oferecem para problemas enc...
# 2   Como faço para obter um arquivo com o registro...
# 3   Qual é o número de telefone para atendimento s...
# 4   Como posso deixar uma avaliação positiva sobre...
# ..                                                ...
# 74  Como faço para acessar os serviços de Imposto ...
# 75  Como um MEI pode acessar e melhorar o nível da...
# 76  Como posso acessar os serviços do Meu INSS se ...
# 77  Como posso acessar e utilizar o sistema Regist...
# 78  Como posso consultar e solicitar a devolução d...
#
#                                     classe  \
# 0           Geral – Atendimento Presencial
# 1    Geral - Problema em sistemas diversos
# 2      Geral - Arquivo da conversa no chat
# 3           Geral - Atendimento telefônico
# 4                          Geral - Elogios
# ..                                     ...
# ...

# %%
df.iloc[75]["response_dify"]
# Out:
# 'Olá! Eu sou o assistente do gov.br e estou aqui para ajudar com suas dúvidas sobre a Conta GOV.BR.\n\nPara um MEI acessar e melhorar o nível da sua conta, o procedimento é o seguinte:\n\n1. Você deve seguir as orientações disponíveis em uma página específica que instruirá como obter uma conta GOV.BR com nível Prata, que já é suficiente para muitos serviços digitais, ou avançar para os níveis Prata ou Ouro conforme necessário.\n\n2. O processo é feito no ambiente do seu banco, utilizando a base de dados já registrada na instituição de origem. Vale lembrar que cada banco possui um procedimento próprio para autenticar seus clientes.\n\nPara mais informações e para acessar o serviço, visite o portal gov.br.\n\nSe precisar de mais alguma orientação sobre a Conta GOV.BR, estou à disposição para ajudar!'

# %%
df.to_csv("dify-11.06.2025.csv", index=False)

# %%
df
# Out:
#                                              pergunta  \
# 0   Quais serviços estão disponíveis nos balcões d...
# 1   Qual suporte vocês oferecem para problemas enc...
# 2   Como faço para obter um arquivo com o registro...
# 3   Qual é o número de telefone para atendimento s...
# 4   Como posso deixar uma avaliação positiva sobre...
# ..                                                ...
# 74  Como faço para acessar os serviços de Imposto ...
# 75  Como um MEI pode acessar e melhorar o nível da...
# 76  Como posso acessar os serviços do Meu INSS se ...
# 77  Como posso acessar e utilizar o sistema Regist...
# 78  Como posso consultar e solicitar a devolução d...
#
#                                     classe  \
# 0           Geral – Atendimento Presencial
# 1    Geral - Problema em sistemas diversos
# 2      Geral - Arquivo da conversa no chat
# 3           Geral - Atendimento telefônico
# 4                          Geral - Elogios
# ..                                     ...
# ...
